# %% [markdown]
# **DisneylandReviews 예제로 Pandas, Numpy 학습**

# %%
import numpy as np
import pandas as pd

# %%
df_disney = pd.read_csv("0.dataSet/DisneylandReviews.csv")
df_disney
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %%
df_disney.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
df_disney.tail()
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 42651    1765031       5    missing    United Kingdom
# 42652    1659553       5    missing            Canada
# 42653    1645894       5    missing      South Africa
# 42654    1618637       4    missing     United States
# 42655    1536786       4    missing    United Kingdom
#
#                                              Review_Text            Branch
# 42651  i went to disneyland paris in july 03 and thou...  Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...  Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...  Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...  Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...  Disneyland_Paris

# %%
print(type(df_disney))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_disney.describe()
# Out:
#           Review_ID        Rating
# count  4.265600e+04  42656.000000
# mean   3.188553e+08      4.217695
# std    1.657092e+08      1.063371
# min    1.398724e+06      1.000000
# 25%    1.743274e+08      4.000000
# 50%    2.907583e+08      5.000000
# 75%    4.489579e+08      5.000000
# max    6.708014e+08      5.000000

# %%
df_disney.index
# Out:
# RangeIndex(start=0, stop=42656, step=1)

# %%
df_disney.values
# Out:
# array([[670772142, 4, '2019-4', 'Australia',
#         "If you've ever been to Disneyland anywhere you'll find Disneyland Hong Kong very similar in the layout when you walk into main street! It has a very familiar feel. One of the rides  its a Small World  is absolutely fabulous and worth doing. The day we visited was fairly hot and relatively busy but the queues moved fairly well. ",
#         'Disneyland_HongKong'],
#        [670682799, 4, '2019-5', 'Philippines',
# ...

# %%
df_disney.value_counts
# Out:
# <bound method DataFrame.value_counts of        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# ...

# %%
df_disney.value_counts(normalize=True)
# Out:
# Review_ID  Rating  Year_Month  Reviewer_Location  Review_Text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
df_disney.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-45c922c27b34> in <module>
# ----> 1 df_disney.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df_disney['Reviewer_Location'].unique()
# Out:
# array(['Australia', 'Philippines', 'United Arab Emirates',
#        'United Kingdom', 'Singapore', 'India', 'Malaysia',
#        'United States', 'Canada', 'Myanmar (Burma)', 'Hong Kong', 'China',
#        'Indonesia', 'Qatar', 'New Zealand', 'Sri Lanka', 'Uganda',
#        'Thailand', 'Austria', 'South Africa', 'Saudi Arabia', 'Japan',
#        'Israel', 'South Korea', 'Turkey', 'Macau', 'Egypt', 'Mexico',
#        'Mauritius', 'Sweden', 'Brazil', 'Kenya', 'Vietnam', 'Portugal',
#        'Cambodia', 'Zambia', 'Croatia', 'France', 'Taiwan', 'Oman',
#        'Colombia', 'Norway', 'Kuwait', 'Netherlands', 'Barbados',
#        'Finland', 'Bosnia and Herzegovina', 'Brunei', 'Bahrain',
#        'Maldives', 'Ireland', 'Russia', 'Romania',
#        'Northern Mariana Islands', 'Germany', 'Chile', 'Isle of Man',
#        'Pakistan', 'Ukraine', 'Greece', 'Switzerland', 'Spain', 'Estonia',
#        "C?e d'Ivoire", 'Guam', 'Bangladesh', 'Belgium', 'Italy',
# ...

# %%
df_disney.take([1,2])
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
#
#                                          Review_Text               Branch
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong

# %%
df_disney.iloc[[100,200]]
# Out:
#      Review_ID  Rating Year_Month Reviewer_Location  \
# 100  662664830       3     2019-2             India
# 200  653385350       5     2019-2     United States
#
#                                            Review_Text               Branch
# 100  It   s a very huge game cum theme park, so if ...  Disneyland_HongKong
# 200  Much smaller than the US versions and you can ...  Disneyland_HongKong

# %%
df_disney[['Year_Month', 'Branch']]
# Out:
#       Year_Month               Branch
# 0         2019-4  Disneyland_HongKong
# 1         2019-5  Disneyland_HongKong
# 2         2019-4  Disneyland_HongKong
# 3         2019-4  Disneyland_HongKong
# 4         2019-4  Disneyland_HongKong
# ...          ...                  ...
# 42651    missing     Disneyland_Paris
# 42652    missing     Disneyland_Paris
# 42653    missing     Disneyland_Paris
# 42654    missing     Disneyland_Paris
# 42655    missing     Disneyland_Paris
#
# [42656 rows x 2 columns]

# %%
df_disney.value_counts('Rating')
# Out:
# Rating
# 5    23146
# 4    10775
# 3     5109
# 2     2127
# 1     1499
# dtype: int64

# %%
df_disney['Rating'].value_counts(dropna=False)
# Out:
# 5    23146
# 4    10775
# 3     5109
# 2     2127
# 1     1499
# Name: Rating, dtype: int64

# %%
df_disney.index
# Out:
# RangeIndex(start=0, stop=42656, step=1)

# %%
df_disney.columns
# Out:
# Index(['Review_ID', 'Rating', 'Year_Month', 'Reviewer_Location', 'Review_Text',
#        'Branch'],
#       dtype='object')

# %%
df_disney.count()
# Out:
# Review_ID            42656
# Rating               42656
# Year_Month           42656
# Reviewer_Location    42656
# Review_Text          42656
# Branch               42656
# dtype: int64

# %%
type(df_disney['Year_Month'])
# Out:
# pandas.core.series.Series

# %%
df_disney['Year_Month'].value_counts(dropna=False)
# Out:
# missing    2613
# 2015-8      786
# 2015-7      759
# 2015-12     701
# 2015-6      692
#            ...
# 2010-8        7
# 2010-5        4
# 2019-5        2
# 2010-3        2
# 2010-4        1
# Name: Year_Month, Length: 112, dtype: int64

# %%
s = pd.Series(df_disney['Year_Month'].dropna())
s.value_counts(dropna=False)
# Out:
# missing    2613
# 2015-8      786
# 2015-7      759
# 2015-12     701
# 2015-6      692
#            ...
# 2010-8        7
# 2010-5        4
# 2019-5        2
# 2010-3        2
# 2010-4        1
# Name: Year_Month, Length: 112, dtype: int64

# %%
df_disney.ndim
# Out:
# 2

# %%
df_disney.shape
# Out:
# (42656, 6)

# %%
df_disney1 = pd.concat([df_disney, s])
df_disney1
# Out:
#              0               Branch  Rating    Review_ID  \
# 0          NaN  Disneyland_HongKong     4.0  670772142.0
# 1          NaN  Disneyland_HongKong     4.0  670682799.0
# 2          NaN  Disneyland_HongKong     4.0  670623270.0
# 3          NaN  Disneyland_HongKong     4.0  670607911.0
# 4          NaN  Disneyland_HongKong     4.0  670607296.0
# ...        ...                  ...     ...          ...
# 42651  missing                  NaN     NaN          NaN
# 42652  missing                  NaN     NaN          NaN
# 42653  missing                  NaN     NaN          NaN
# 42654  missing                  NaN     NaN          NaN
# 42655  missing                  NaN     NaN          NaN
#
#                                              Review_Text  \
# 0      If you've ever been to Disneyland anywhere you...
# 1      Its been a while since d last time we visit HK...
# 2      Thanks God it wasn   t too hot or too humid wh...
# ...

# %%
df_disney2 = pd.concat([df_disney, s], axis=1)
df_disney2
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %%
df_disney.sort_values(by='Rating', ascending=True)
# Out:
#        Review_ID  Rating Year_Month         Reviewer_Location  \
# 25271  148046893       1    missing  Turks and Caicos Islands
# 6653   239160649       1    2014-10                 Australia
# 33072  429014168       1     2016-5                   Czechia
# 33039  430636694       1    2016-10               Netherlands
# 21438  218942479       1     2014-7             United States
# ...          ...     ...        ...                       ...
# 11084  574949379       5     2018-4             United States
# 24700  155939460       5     2013-3                    Canada
# 24699  155940018       5     2013-3             United States
# 24710  155847738       5     2013-3                 Australia
# 28900    5523980       5    missing                 Australia
#
#                                              Review_Text  \
# 25271  fastpass is a con. You can only check in yup o...
# 6653   I am so glad that I have been lucky enough to ...
# ...

# %%
df_disney.sort_values(by='Year_Month', ascending=True)
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 28251  118010038       5    2010-10     United States
# 28426  112342838       5    2010-10         Australia
# 28407  113951461       5    2010-10     United States
# 28367  115918375       4    2010-10     United States
# 28330  116603111       5    2010-10         Australia
# ...          ...     ...        ...               ...
# 28687   46306256       4    missing     United States
# 28688   46305610       5    missing     United States
# 28689   46295035       5    missing     United States
# 28676   46776242       5    missing     United States
# 42655    1536786       4    missing    United Kingdom
#
#                                              Review_Text  \
# 28251  The Disney Land Half Marathon was one of the b...
# 28426  Had a great and fun time visiting Disneyland. ...
# 28407  I have been to Disneyland numerous times, duri...
# 28367  Disneyland is a personal experience. My opinio...
# ...

# %%
df_disney.sort_values(by='Rating', ascending=False)
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 21328  221443117       5     2013-9     United States
# 17656  310933989       5     2015-8    United Kingdom
# 17654  311025331       5     2015-9    United Kingdom
# 17653  311045924       5     2015-7     United States
# 17652  311068724       5     2015-9         Australia
# ...          ...     ...        ...               ...
# 21438  218942479       1     2014-7     United States
# 13268  467863382       1     2017-3     United States
# 38368  202279052       1     2013-5             Malta
# 38370  202237686       1     2014-4    United Kingdom
# 33706  388534006       1     2016-7         Australia
#
#                                              Review_Text  \
# 21328  Disneyland has been a favorite since I was 5 y...
# 17656  As they say Disneyland is the place dreams are...
# 17654  I was there for a week prior to Labour Day and...
# 17653  What can I say about Disneyland and California...
# ...

# %%
df_disney.sort_values(by='Year_Month', ascending=False)
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 42655    1536786       4    missing    United Kingdom
# 27101  126691749       2    missing     United States
# 27086  126744883       5    missing     United States
# 27082  126749385       4    missing     United States
# 27070  126766217       5    missing     United States
# ...          ...     ...        ...               ...
# 41818  118459970       5    2010-10     United States
# 28251  118010038       5    2010-10     United States
# 28258  117990655       4    2010-10         Argentina
# 28330  116603111       5    2010-10         Australia
# 28407  113951461       5    2010-10     United States
#
#                                              Review_Text  \
# 42655  I went to the Disneyparis resort, in 1996, wit...
# 27101  You had to park far from the park, take an esc...
# 27086  Just magical! I am an annual pass holder and I...
# 27082  Again, Disney knows how to do it but if you al...
# ...

# %%
df_disney.Year_Month
# Out:
# 0         2019-4
# 1         2019-5
# 2         2019-4
# 3         2019-4
# 4         2019-4
#           ...
# 42651    missing
# 42652    missing
# 42653    missing
# 42654    missing
# 42655    missing
# Name: Year_Month, Length: 42656, dtype: object

# %%
df_disney['Year_Month']
# Out:
# 0         2019-4
# 1         2019-5
# 2         2019-4
# 3         2019-4
# 4         2019-4
#           ...
# 42651    missing
# 42652    missing
# 42653    missing
# 42654    missing
# 42655    missing
# Name: Year_Month, Length: 42656, dtype: object

# %%
df_disney[0:10]
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
# 5  670591897       3     2019-4             Singapore
# 6  670585330       5     2019-4                 India
# 7  670574142       3     2019-3              Malaysia
# 8  670571027       2     2019-4             Australia
# 9  670570869       5     2019-3                 India
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# ...

# %%
a = df_disney['Year_Month'] = pd.Series(df_disney['Year_Month'], dtype='int64')
a
# Out:
# 0         2019-4
# 1         2019-5
# 2         2019-4
# 3         2019-4
# 4         2019-4
#           ...
# 42651    missing
# 42652    missing
# 42653    missing
# 42654    missing
# 42655    missing
# Name: Year_Month, Length: 42656, dtype: object
